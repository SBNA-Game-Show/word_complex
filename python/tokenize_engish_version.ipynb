# %%
import os
import json
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
file_path = os.path.join("data","stories.json")
print(file_path)
# Out:
# data/stories.json

# %%
stories =[]

# %%
with open(file_path, "r", encoding="utf-8") as f:
    stories = json.load(f)

print(stories)
# Out:
# {'title': 'rabbit, weasel, cat', 'actors': ['rabbit', 'weasel', 'cat'], 'storyMoral': 'The strong can settle questions to their own advantage', 'englishVersion': 'When the rabbit left his home, a weasel moved in and refused to move out again. A great dispute arose over this.  When the cat heard this, she offered to pacify the dispute. She asked the opponents to come closer to her, because she could not hear well. When this happened, she grabbed one of the disputants with each paw to devour them. Thus she pacified the quarrel.', 'transliteratedVersion': ['zazakaH nakulaH mArjArI ca', 'ekadine gRhAt prasthitaH ekaH zazakaH svAduM tRNaM khAditum agacchat ।', 'parantu gRhasya pidhAnaM kartuM saH vismRtavAn ।', 'yadA zazakaH gRhe na AsIt tadA ekaH nakulaH tatra Agatya zazakasya gRhaM praviSTavAn ।', 'tasmai zazakasya gRham arocata ataH tatraiva nivasituM nizcayaM kRtavAn ।', 'zazakaH Agatya nakulaM dRSTvA ca avadat –', '" mama gRhAt nirgacchatu zIghram " – iti ।', 'parantu nakulaH gantuM 
# ...

# %%
english_version_story = stories["englishVersion"]
print(english_version_story)
# Out:
# When the rabbit left his home, a weasel moved in and refused to move out again. A great dispute arose over this.  When the cat heard this, she offered to pacify the dispute. She asked the opponents to come closer to her, because she could not hear well. When this happened, she grabbed one of the disputants with each paw to devour them. Thus she pacified the quarrel.

# %%
doc =nlp(english_version_story)
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# When when SCONJ WRB advmod Xxxx True True
# the the DET DT det xxx True True
# rabbit rabbit NOUN NN nsubj xxxx True False
# left leave VERB VBD advcl xxxx True False
# his his PRON PRP$ poss xxx True True
# home home NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# a a DET DT det x True True
# weasel weasel NOUN NN nsubj xxxx True False
# moved move VERB VBD ROOT xxxx True False
# in in ADV RB advmod xx True True
# and and CCONJ CC cc xxx True True
# refused refuse VERB VBD conj xxxx True False
# to to PART TO aux xx True True
# move move VERB VB xcomp xxxx True True
# out out ADP RP prt xxx True True
# again again ADV RB advmod xxxx True True
# . . PUNCT . punct . False False
# A a DET DT det X True True
# great great ADJ JJ amod xxxx True False
# dispute dispute NOUN NN nsubj xxxx True False
# arose arise VERB VBD ROOT xxxx True False
# over over ADP IN prep xxxx True True
# this this PRON DT pobj xxxx True True
# . . PUNCT . punct . False False
# ...

# %%
doc = nlp(english_version_story)

tagged_words = []

for token in doc:
    tagged_words.append({
        "text": token.text,
        # "lemma": token.lemma_,
        "pos": token.pos_,
        # "tag": token.tag_,
        # "dep": token.dep_,
        # "shape": token.shape_,
        # "is_alpha": token.is_alpha,
        # "is_stop": token.is_stop
    })

print(tagged_words)
# Out:
# [{'text': 'When', 'pos': 'SCONJ'}, {'text': 'the', 'pos': 'DET'}, {'text': 'rabbit', 'pos': 'NOUN'}, {'text': 'left', 'pos': 'VERB'}, {'text': 'his', 'pos': 'PRON'}, {'text': 'home', 'pos': 'NOUN'}, {'text': ',', 'pos': 'PUNCT'}, {'text': 'a', 'pos': 'DET'}, {'text': 'weasel', 'pos': 'NOUN'}, {'text': 'moved', 'pos': 'VERB'}, {'text': 'in', 'pos': 'ADV'}, {'text': 'and', 'pos': 'CCONJ'}, {'text': 'refused', 'pos': 'VERB'}, {'text': 'to', 'pos': 'PART'}, {'text': 'move', 'pos': 'VERB'}, {'text': 'out', 'pos': 'ADP'}, {'text': 'again', 'pos': 'ADV'}, {'text': '.', 'pos': 'PUNCT'}, {'text': 'A', 'pos': 'DET'}, {'text': 'great', 'pos': 'ADJ'}, {'text': 'dispute', 'pos': 'NOUN'}, {'text': 'arose', 'pos': 'VERB'}, {'text': 'over', 'pos': 'ADP'}, {'text': 'this', 'pos': 'PRON'}, {'text': '.', 'pos': 'PUNCT'}, {'text': ' ', 'pos': 'SPACE'}, {'text': 'When', 'pos': 'SCONJ'}, {'text': 'the', 'pos': 'DET'}, {'text': 'cat', 'pos': 'NOUN'}, {'text': 'heard', 'pos': 'VERB'}, {'text': 'this', 'pos'
# ...

# %%
with open(file_path, "r", encoding="utf-8") as f:
    story = json.load(f)

# 2. Add new field
story["tokenized_english_version"] = tagged_words

# 3. Save back to file
with open(file_path, "w", encoding="utf-8") as f:
    json.dump(story, f, indent=4, ensure_ascii=False)

print("Tokenized data added successfully!")
# Out:
# Tokenized data added successfully!
